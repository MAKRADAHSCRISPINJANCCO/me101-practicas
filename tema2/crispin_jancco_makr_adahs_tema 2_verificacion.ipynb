# %%
import pandas as pd
import numpy as np
print("el entorno esta corriendo correctamente")
print("pandas", pd.__version__, "numpy", np.__version__)
# Out:
# el entorno esta corriendo correctamente
# pandas 3.0.5 numpy 2.5.2
